# %%
import pandas as pd

# %%
df = pd.read_csv('./data/processed_data/matches_sorted.csv')

# %%
df.head(n=40)
# Out:
#     Unnamed: 0  TOP_total_games  TOP_wins  TOP_TOP_kills  TOP_TOP_deaths  \
# 0            0                1         1       0.000000        0.058766
# 1            1                1         0       0.058766        0.235064
# 2            2                1         1       0.199071        0.039814
# 3            3                1         0       0.119443        0.119443
# 4            4                1         0       0.237691        0.271647
# 5            5                1         1       0.169779        0.271647
# 6            6                1         0       0.000000        0.234375
# 7            7                1         1       0.468750        0.000000
# 8            8                1         1       0.088365        0.088365
# 9            9                1         0       0.088365        0.220913
# 10          10                1         1       0.188088        0.188088
# 11          11                1         0       0.094044        0.470219
# ...

# %%
df.tail(n=40)
# Out:
#         Unnamed: 0  TOP_total_games  TOP_wins  TOP_TOP_kills  TOP_TOP_deaths  \
# 156304      156304              146        80       0.249591        0.155642
# 156305      156305              282       141       0.238953        0.181141
# 156306      156306              330       176       0.190359        0.180061
# 156307      156307              375       196       0.123462        0.161127
# 156308      156308              440       218       0.211214        0.190478
# 156309      156309              102        63       0.235880        0.137451
# 156310      156310              407       209       0.118111        0.164102
# 156311      156311              208       120       0.202777        0.143713
# 156312      156312              493       256       0.178429        0.202625
# 156313      156313              207       110       0.142566        0.153634
# 156314      156314              420       212       0.253035        0.156516
# ...
