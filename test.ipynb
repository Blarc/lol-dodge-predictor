# %%
import pandas as pd

# %%
df = pd.read_csv('./data/processed_data/matches_sorted.csv')

# %%
df.head(n=40)
# Out:
#     Unnamed: 0  TOP_total_games  TOP_wins  TOP_TOP_kills  TOP_TOP_deaths  \
# 0            0                1         1       0.000000        0.058766
# 1            1                1         0       0.058766        0.235064
# 2            2                2         2       0.000000        0.058766
# 3            3                2         0       0.058766        0.235064
# 4            4                1         1       0.199071        0.039814
# 5            5                1         0       0.119443        0.119443
# 6            6                2         2       0.199071        0.039814
# 7            7                2         0       0.119443        0.119443
# 8            8                1         0       0.237691        0.271647
# 9            9                1         1       0.169779        0.271647
# 10          10                2         0       0.237691        0.271647
# 11          11                2         2       0.169779        0.271647
# ...

# %%
df.tail(n=40)
# Out:
#         Unnamed: 0  TOP_total_games  TOP_wins  TOP_TOP_kills  TOP_TOP_deaths  \
# 312648      312648              479       263       0.107436        0.134114
# 312649      312649              429       244       0.080562        0.137956
# 312650      312650              480       264       0.107895        0.132824
# 312651      312651              430       244       0.079646        0.139474
# 312652      312652               97        53       0.211455        0.154263
# 312653      312653             1081       532       0.200167        0.191815
# 312654      312654               98        54       0.209150        0.154814
# 312655      312655             1082       532       0.201369        0.191605
# 312656      312656              939       500       0.208949        0.183585
# 312657      312657              815       423       0.199866        0.181477
# 312658      312658              940       500       0.208654        0.183843
# ...
