# %%
from time import time
from pprint import pprint

import pandas as pd

from riotapi import *

# %% [markdown]
# ## Data
#
# We get 100 players from diamond 1.

# %%
players_data = get_players_in_diamond1()[0:100]

# %% [markdown]
# We then loop through all the players and gather their data about recent solo ranked games and save them as csv.

# %%
for player_data in players_data:
    summoner_name = player_data['summonerName']
    try:
        match_references = get_match_references_by_username(summoner_name, 0, 20)
    except:
        print(f"Error. Skipping {summoner_name}")
        continue


    print("------------------------------------------------------------------------")
    print(f"Gathering data for {summoner_name}...")
    startTime = time()

    match_list = []
    for match_reference in match_references:
        champion = match_reference['champion']
        role = match_reference['role']
        lane = match_reference['lane']
        game_id = match_reference['gameId']

        try:
            game = get_match_by_id(game_id)
        except:
            print(f"Error. Skipping game {game_id} for summoner {summoner_name}")
            continue

        if game == "404":
            continue

        participants = game['participants']

        # We need to find the participant that matches with the champion
        participant = None
        for p in participants:
            if p['championId'] == champion:
                participant = p
                break

        participant_stats = participant['stats']
        win = participant_stats['win']
        kills = participant_stats['kills']
        deaths = participant_stats['deaths']
        assists = participant_stats['assists']
        total_damage_dealt_to_champions = participant_stats['totalDamageDealtToChampions']
        vision_score = participant_stats['visionScore']
        gold_earned = participant_stats['goldEarned']
        total_minions_killed = participant_stats['totalMinionsKilled']

        match_list.append([champion, role, lane, win, kills, deaths, assists, total_damage_dealt_to_champions, vision_score, gold_earned, total_minions_killed])

    print(f"Time: {time() - startTime}")
    dataset = pd.DataFrame(match_list)
    dataset.columns = ['champion', 'role', 'lane', 'win', 'kills', 'deaths', 'assists', 'total_damage_dealt_to_champions', 'vision_score', 'gold_earned', 'total_minions_killed']
    dataset.to_csv(f'././data/{summoner_name}.csv', index=False, header=True)
    print(f"Saved to data/{summoner_name}.csv")
# Out:
# ------------------------------------------------------------------------
# Gathering data for soloitude...
# Time: 47.928781270980835
# Saved to data/soloitude.csv
# ------------------------------------------------------------------------
# Gathering data for New opportunity ...
# Time: 48.128347873687744
# Saved to data/New opportunity .csv
# ------------------------------------------------------------------------
# Gathering data for Starduster...
# Time: 48.835631370544434
# Saved to data/Starduster.csv
# ------------------------------------------------------------------------
# Gathering data for Real KMS Hours...
# Time: 48.04931616783142
# Saved to data/Real KMS Hours.csv
# ------------------------------------------------------------------------
# Gathering data for CursedTop...
# Time: 48.084731101989746
# Saved to data/CursedTop.csv
# ------------------------------------------------------------------------
# Gathering data for Huskigodx...
# Time: 48.185394525527954
# Saved to data/Huskigodx.csv
# ------------------------------------------------------------------------
# Gathering data for Ghiosu...
# Time: 48.08973670005798
# Saved to data/Ghiosu.csv
# ------------------------------------------------------------------------
# Gathering data for Spitzweck...
# Time: 48.19342374801636
# Saved to data/Spitzweck.csv
# ------------------------------------------------------------------------
# Gathering data for Bazippo...
# Time: 48.308626651763916
# Saved to data/Bazippo.csv
# ------------------------------------------------------------------------
# Gathering data for Nifty Gamer...
# Time: 48.07781910896301
# Saved to data/Nifty Gamer.csv
# ------------------------------------------------------------------------
# Gathering data for IiNayo...
# Time: 48.069068908691406
# Saved to data/IiNayo.csv
# ------------------------------------------------------------------------
# Gathering data for ItsMediated...
# ERROR: 504. Sleeping for 120s.
# Retrying...
# Time: 169.45677614212036
# Saved to data/ItsMediated.csv
# ------------------------------------------------------------------------
# Gathering data for IceGlaceon...
# Time: 48.00180697441101
# Saved to data/IceGlaceon.csv
# ------------------------------------------------------------------------
# Gathering data for PG Moller v2...
# Time: 47.96924829483032
# Saved to data/PG Moller v2.csv
# ------------------------------------------------------------------------
# Gathering data for bepu in da house...
# Time: 48.21881580352783
# Saved to data/bepu in da house.csv
# ------------------------------------------------------------------------
# Gathering data for Exun...
# Time: 48.00453186035156
# Saved to data/Exun.csv
# ------------------------------------------------------------------------
# Gathering data for Forbenn...
# Time: 48.0558967590332
# Saved to data/Forbenn.csv
# ------------------------------------------------------------------------
# Gathering data for LFT Outlandisch...
# Time: 48.076716899871826
# Saved to data/LFT Outlandisch.csv
# ------------------------------------------------------------------------
# Gathering data for Morello Salesman...
# Time: 47.927408933639526
# Saved to data/Morello Salesman.csv
# ------------------------------------------------------------------------
# Gathering data for   Toti Gible...
# ERROR: 504. Sleeping for 120s.
# Retrying...
# ERROR: 504. Sleeping for 120s.
# Retrying...
# Time: 290.82487630844116
# Saved to data/  Toti Gible.csv
# ------------------------------------------------------------------------
# Gathering data for Random Plâyer...
# Time: 48.31617999076843
# Saved to data/Random Plâyer.csv
# ------------------------------------------------------------------------
# Gathering data for Deelix...
# Time: 48.04915499687195
# Saved to data/Deelix.csv
# ------------------------------------------------------------------------
# Gathering data for PAUL PUNISHER...
# Time: 48.12899899482727
# Saved to data/PAUL PUNISHER.csv
# ------------------------------------------------------------------------
# Gathering data for AziNοx...
# Time: 48.160972595214844
# Saved to data/AziNοx.csv
# ------------------------------------------------------------------------
# Gathering data for LECSUPERSTARSUPP...
# Time: 48.22389364242554
# Saved to data/LECSUPERSTARSUPP.csv
# ------------------------------------------------------------------------
# Gathering data for i have faith...
# Time: 48.27441740036011
# Saved to data/i have faith.csv
# ------------------------------------------------------------------------
# Gathering data for Kaeloo v2...
# Time: 48.0605194568634
# Saved to data/Kaeloo v2.csv
# ------------------------------------------------------------------------
# Gathering data for Cow1337killr...
# Time: 47.98730778694153
# Saved to data/Cow1337killr.csv
# ------------------------------------------------------------------------
# Gathering data for Young Bratz...
# Time: 48.14736843109131
# Saved to data/Young Bratz.csv
# ------------------------------------------------------------------------
# Gathering data for Tilted Alice...
# Time: 48.163278102874756
# Saved to data/Tilted Alice.csv
# ------------------------------------------------------------------------
# Gathering data for L O L U S...
# Time: 48.03317332267761
# Saved to data/L O L U S.csv
# ------------------------------------------------------------------------
# Gathering data for Iron 1 Smurf...
# ERROR: 504. Sleeping for 120s.
# Retrying...
# Time: 169.3660762310028
# Saved to data/Iron 1 Smurf.csv
# ------------------------------------------------------------------------
# Gathering data for KING MANATY...
# Time: 47.99686026573181
# Saved to data/KING MANATY.csv
# ------------------------------------------------------------------------
# Gathering data for OneBaldGuy...
# Time: 47.99886655807495
# Saved to data/OneBaldGuy.csv
# ------------------------------------------------------------------------
# Gathering data for CalQina4...
# Time: 48.125022649765015
# Saved to data/CalQina4.csv
# ------------------------------------------------------------------------
# Gathering data for XIOAXINAAA ...
# Time: 47.989168643951416
# Saved to data/XIOAXINAAA .csv
# ------------------------------------------------------------------------
# Gathering data for Clarence Worley...
# Time: 48.34410095214844
# Saved to data/Clarence Worley.csv
# ------------------------------------------------------------------------
# Gathering data for grl no hand...
# Time: 48.173869132995605
# Saved to data/grl no hand.csv
# ------------------------------------------------------------------------
# Gathering data for Bardd...
# Time: 48.204567670822144
# Saved to data/Bardd.csv
# ------------------------------------------------------------------------
# Gathering data for Europe Unchained...
# Time: 47.955575942993164
# Saved to data/Europe Unchained.csv
# ------------------------------------------------------------------------
# Gathering data for Hrvatko...
# Time: 47.93802285194397
# Saved to data/Hrvatko.csv
# ------------------------------------------------------------------------
# Gathering data for Siusiak Hombre...
# ERROR: 504. Sleeping for 120s.
# Retrying...
# Time: 169.43469309806824
# Saved to data/Siusiak Hombre.csv
# ------------------------------------------------------------------------
# Gathering data for Tobykachu...
# Time: 48.049012184143066
# Saved to data/Tobykachu.csv
# ------------------------------------------------------------------------
# Gathering data for Fliomag...
# Time: 47.88302564620972
# Saved to data/Fliomag.csv
# ------------------------------------------------------------------------
# Gathering data for im inting GLDOGS...
# Time: 47.934396743774414
# Saved to data/im inting GLDOGS.csv
# ------------------------------------------------------------------------
# Gathering data for Yunn...
# Time: 48.05153799057007
# Saved to data/Yunn.csv
# ------------------------------------------------------------------------
# Gathering data for Mettwurst...
# Time: 48.11271572113037
# Saved to data/Mettwurst.csv
# ------------------------------------------------------------------------
# Gathering data for Reformed Reppy...
# Time: 48.27065300941467
# Saved to data/Reformed Reppy.csv
# ------------------------------------------------------------------------
# Gathering data for Be your deer...
# Time: 48.128597259521484
# Saved to data/Be your deer.csv
# ------------------------------------------------------------------------
# Gathering data for Aincardz...
# Time: 47.90044450759888
# Saved to data/Aincardz.csv
# ------------------------------------------------------------------------
# Gathering data for peagod...
# Time: 48.00793695449829
# Saved to data/peagod.csv
# ------------------------------------------------------------------------
# Gathering data for HC Potent...
# Time: 47.979676246643066
# Saved to data/HC Potent.csv
# ------------------------------------------------------------------------
# Gathering data for Senyousart...
# Time: 48.13749647140503
# Saved to data/Senyousart.csv
# ------------------------------------------------------------------------
# Gathering data for Tìzio...
# Time: 47.992345571517944
# Saved to data/Tìzio.csv
# ------------------------------------------------------------------------
# Gathering data for Song Ran...
# Time: 48.20887279510498
# Saved to data/Song Ran.csv
# ------------------------------------------------------------------------
# Gathering data for Hodný kluk...
# Time: 47.94478392601013
# Saved to data/Hodný kluk.csv
# ------------------------------------------------------------------------
# Gathering data for Kyuuba...
# Time: 48.196223974227905
# Saved to data/Kyuuba.csv
# ------------------------------------------------------------------------
# Gathering data for Hi Im Brko...
# Time: 48.05243110656738
# Saved to data/Hi Im Brko.csv
# ------------------------------------------------------------------------
# Gathering data for kasadei...
# Time: 48.03024101257324
# Saved to data/kasadei.csv
# ------------------------------------------------------------------------
# Gathering data for Suchex...
# Time: 48.42895436286926
# Saved to data/Suchex.csv
# ------------------------------------------------------------------------
# Gathering data for Hula Hoop Lady...
# Time: 47.971821546554565
# Saved to data/Hula Hoop Lady.csv
# ------------------------------------------------------------------------
# Gathering data for Bloody1...
# Time: 47.903597831726074
# Saved to data/Bloody1.csv
# ------------------------------------------------------------------------
# Gathering data for Latch1...
# ERROR: 504. Sleeping for 120s.
# Retrying...
# Time: 169.46315550804138
# Saved to data/Latch1.csv
# ------------------------------------------------------------------------
# Gathering data for I Dont Own Janna...
# Time: 48.157270193099976
# Saved to data/I Dont Own Janna.csv
# ------------------------------------------------------------------------
# Gathering data for Rajot Piernik...
# Time: 48.01624846458435
# Saved to data/Rajot Piernik.csv
# ------------------------------------------------------------------------
# Gathering data for 7bts...
# Time: 48.287970304489136
# Saved to data/7bts.csv
# ------------------------------------------------------------------------
# Gathering data for Stranger Twings...
# Time: 48.16591215133667
# Saved to data/Stranger Twings.csv
# ------------------------------------------------------------------------
# Gathering data for Five Degrees X...
# Time: 48.093082427978516
# Saved to data/Five Degrees X.csv
# ------------------------------------------------------------------------
# Gathering data for Majord Gerald...
# Time: 48.29965019226074
# Saved to data/Majord Gerald.csv
# ERROR 404: skipping...
# Error. Skipping tempname8515
# ------------------------------------------------------------------------
# Gathering data for wThPete...
# Time: 48.84584999084473
# Saved to data/wThPete.csv
# ------------------------------------------------------------------------
# Gathering data for Perhimloth...
# Time: 48.14813256263733
# Saved to data/Perhimloth.csv
# ------------------------------------------------------------------------
# Gathering data for DLay...
# Time: 48.16819977760315
# Saved to data/DLay.csv
# ------------------------------------------------------------------------
# Gathering data for Faker JA...
# Time: 47.816370725631714
# Saved to data/Faker JA.csv
# ------------------------------------------------------------------------
# Gathering data for Kαt4Reset...
# Time: 47.9076361656189
# Saved to data/Kαt4Reset.csv
# ------------------------------------------------------------------------
# Gathering data for Rank 1 Südtirol...
# Time: 47.88319396972656
# Saved to data/Rank 1 Südtirol.csv
# ------------------------------------------------------------------------
# Gathering data for eGz Fear...
# Time: 47.948081970214844
# Saved to data/eGz Fear.csv
# ------------------------------------------------------------------------
# Gathering data for Sonne3214...
# Time: 48.141708850860596
# Saved to data/Sonne3214.csv
# ------------------------------------------------------------------------
# Gathering data for Tykkimies...
# Time: 48.255460262298584
# Saved to data/Tykkimies.csv
# ------------------------------------------------------------------------
# Gathering data for Elyscent...
# Time: 48.518484592437744
# Saved to data/Elyscent.csv
# ------------------------------------------------------------------------
# Gathering data for kendifcb...
# Time: 48.093427658081055
# Saved to data/kendifcb.csv
# ------------------------------------------------------------------------
# Gathering data for Diego DIO Brando...
# Time: 48.57524800300598
# Saved to data/Diego DIO Brando.csv
# ------------------------------------------------------------------------
# Gathering data for Acc Pig Tian Xin...
# Time: 48.50131273269653
# Saved to data/Acc Pig Tian Xin.csv
# ------------------------------------------------------------------------
# Gathering data for atoigii...
# Time: 48.479066371917725
# Saved to data/atoigii.csv
# ------------------------------------------------------------------------
# Gathering data for Spirit Cha...
# Time: 48.40151572227478
# Saved to data/Spirit Cha.csv
# ------------------------------------------------------------------------
# Gathering data for Maciej Zaremba...
# Time: 47.990938901901245
# Saved to data/Maciej Zaremba.csv
# ------------------------------------------------------------------------
# Gathering data for KASIMlR...
# Time: 48.11574411392212
# Saved to data/KASIMlR.csv
# ------------------------------------------------------------------------
# Gathering data for AlperSemihAYDIN...
# Time: 48.05854392051697
# Saved to data/AlperSemihAYDIN.csv
# ------------------------------------------------------------------------
# Gathering data for FRB Bruski...
# Time: 47.9342474937439
# Saved to data/FRB Bruski.csv
# ------------------------------------------------------------------------
# Gathering data for SAS Wolf...
# Time: 48.12966966629028
# Saved to data/SAS Wolf.csv
# ------------------------------------------------------------------------
# Gathering data for užsipisimas...
# Time: 48.07056975364685
# Saved to data/užsipisimas.csv
# ------------------------------------------------------------------------
# Gathering data for Vaylišta...
# Time: 48.460681200027466
# Saved to data/Vaylišta.csv
# ------------------------------------------------------------------------
# Gathering data for Shen Yucheng...
# Time: 48.187697649002075
# Saved to data/Shen Yucheng.csv
# ------------------------------------------------------------------------
# Gathering data for Pangar Gossen...
# Time: 48.39328455924988
# Saved to data/Pangar Gossen.csv
# ------------------------------------------------------------------------
# Gathering data for ˇ SaberKuroyuki...
# ERROR: 504. Sleeping for 120s.
# Retrying...
# ERROR: 504. Sleeping for 120s.
# Retrying...
# Time: 291.3628032207489
# Saved to data/ˇ SaberKuroyuki.csv
# ------------------------------------------------------------------------
# Gathering data for Flanegien...
# Time: 48.301902532577515
# Saved to data/Flanegien.csv
# ------------------------------------------------------------------------
# Gathering data for Da1len...
# Time: 47.902735233306885
# Saved to data/Da1len.csv
# ------------------------------------------------------------------------
# Gathering data for Peremees...
# Time: 48.328848123550415
# Saved to data/Peremees.csv
# ------------------------------------------------------------------------
# Gathering data for Imhome...
# Time: 48.20856475830078
# Saved to data/Imhome.csv
# ------------------------------------------------------------------------
# Gathering data for Cancér Game...
# Time: 48.22026777267456
# Saved to data/Cancér Game.csv
