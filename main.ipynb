# %%
from pprint import pprint

from riotapi import *

result = get_match_references_by_username("Blarc")
match = result['matches'][0]
pprint(get_match_by_id(match['gameId']))
# Out:
# {'gameCreation': 1604954973050,
#  'gameDuration': 1327,
#  'gameId': 4918031205,
#  'gameMode': 'CLASSIC',
#  'gameType': 'MATCHED_GAME',
#  'gameVersion': '10.22.341.643',
#  'mapId': 11,
#  'participantIdentities': [{'participantId': 1,
#                             'player': {'accountId': '3TKv0inZMGoyGlwjPQwoUCFp6gknhrt3Z6ea4Wvs_XJ2ICM',
#                                        'currentAccountId': '3TKv0inZMGoyGlwjPQwoUCFp6gknhrt3Z6ea4Wvs_XJ2ICM',
#                                        'currentPlatformId': 'EUW1',
#                                        'matchHistoryUri': '/v1/stats/player_history/EUW1/227886734',
#                                        'platformId': 'EUW1',
#                                        'profileIcon': 980,
#                                        'summonerId': '-YzQWwxWRMkmfMuQhexLjSCffMjsEZgOhYIbflQFzf16vgM',
#                                        'summonerName': 'Crows Guy'}},
#                            {'participantId': 2,
# ...
